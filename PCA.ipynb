# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-mhatre/CS-535-DM/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PCA for Table1

# %%
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('Table1.txt')

# %%
print("Dimensions of the loaded data:", data.shape[1])
# Out:
# Dimensions of the loaded data: 62

# %%
# Standardize the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
pca = PCA()
principal_components = pca.fit_transform(scaled_data)

# %%
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
plt.plot(cumulative_variance_ratio)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Elbow Method for Optimal Number of Components')
plt.grid(True)
plt.show()

# %%
threshold = 0.98
n_components = np.argmax(cumulative_variance_ratio >= threshold) + 1

# %%
pca = PCA(n_components=n_components)
principal_components = pca.fit_transform(scaled_data)

# %%
print("Number of components:", n_components)
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Number of components: 25
# Explained Variance Ratio: [0.31289878 0.18017445 0.14530065 0.09082077 0.04727927 0.03884216
#  0.03212645 0.02598501 0.01887531 0.01190399 0.01126362 0.00990876
#  0.00701918 0.00649659 0.00552407 0.005209   0.00501662 0.00444656
#  0.00366027 0.00354626 0.00321706 0.0029853  0.00288605 0.0027326
#  0.00235043]

# %% [markdown]
# PCA for Table 2

# %%
data2 = np.loadtxt('Table2.txt')

# %%
print("Shape of the loaded data:", data2.shape)
# Out:
# Shape of the loaded data: (67, 62)

# %%
# Standardize the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data2)

# %%
pca = PCA()
principal_components = pca.fit_transform(scaled_data)

# %%
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
plt.plot(cumulative_variance_ratio)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Elbow Method for Optimal Number of Components')
plt.grid(True)
plt.show()

# %%
threshold = 0.98
n_components = np.argmax(cumulative_variance_ratio >= threshold) + 1

# %%
pca = PCA(n_components=n_components)
principal_components = pca.fit_transform(scaled_data)

# %%
print("Number of components:", n_components)
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Number of components: 35
# Explained Variance Ratio: [0.28521627 0.16031032 0.13015345 0.08071155 0.04537997 0.03779072
#  0.02928764 0.02348357 0.01895689 0.01638628 0.01468765 0.01292962
#  0.01204995 0.01036897 0.00947437 0.00924384 0.0077771  0.00721446
#  0.00718049 0.0062658  0.00600859 0.00561119 0.00531388 0.00487416
#  0.00444874 0.00437593 0.00386557 0.00382026 0.0035014  0.00314714
#  0.00293112 0.00270161 0.00232208 0.0021837  0.00192009]

# %% [markdown]
# PCA for Table3

# %%
data3 = np.loadtxt('Table3.txt')

# %%
print("Shape of the loaded data:", data3.shape)
# Out:
# Shape of the loaded data: (67, 62)

# %%
# Standardize the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data3)

# %%
pca = PCA()
principal_components = pca.fit_transform(scaled_data)

# %%
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
plt.plot(cumulative_variance_ratio)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Elbow Method for Optimal Number of Components')
plt.grid(True)
plt.show()

# %%
threshold = 1.0
n_components = np.argmax(cumulative_variance_ratio >= threshold) + 1

# %%
pca = PCA(n_components=n_components)
principal_components = pca.fit_transform(scaled_data)

# %%
print("Number of components:", n_components)
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Number of components: 46
# Explained Variance Ratio: [0.04229798 0.04211754 0.04155919 0.04103915 0.03886046 0.03530792
#  0.03456594 0.03325977 0.03256561 0.0307286  0.02880126 0.02827026
#  0.02583064 0.02294338 0.0220108  0.02153606 0.02138341 0.02130378
#  0.02126508 0.02125471 0.02117699 0.02116553 0.02115154 0.02114899
#  0.02114899 0.02114899 0.02114899 0.02114899 0.02114899 0.02114899
#  0.02114899 0.02114899 0.02114899 0.0202443  0.01633598 0.01448088
#  0.01372947 0.0108686  0.00978922 0.00959659 0.00778243 0.00757313
#  0.00323795 0.00266693 0.00115507 0.00065394]
